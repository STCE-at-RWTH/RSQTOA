# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_results_ann = pd.read_csv('./ann/results.csv')
df_results_grid = pd.read_csv('./grid/results.csv')
df_results_interpolator = pd.read_csv('./interpolator/results.csv')
df_results_lr = pd.read_csv('./elasticnet/results.csv')

# %%
df_time = pd.concat([df_results_lr['train_time'], df_results_ann['train_time'], df_results_grid['train_time'], df_results_interpolator['train_time']], axis=1, keys=['ElasticNet', 'ANN', 'RSQTOA + Grid', 'RSQTOA + Interpolator'])
df_time['fold'] = list(range(1, 21))
df_time
# Out:
#     ElasticNet        ANN  RSQTOA + Grid  RSQTOA + Interpolator  fold
# 0     4.351281  48.779146      23.329611              34.629176     1
# 1     3.653656  44.880514      22.911858              36.966430     2
# 2     3.751978  44.403364      21.855126              38.368923     3
# 3     3.821556  43.045832      22.172382              31.032810     4
# 4     3.644967  43.410006      21.419018              38.907993     5
# 5     3.629871  45.200916      22.583912              35.211401     6
# 6     3.662959  43.410642      21.708088              32.861185     7
# 7     3.684846  45.615894      22.322630              34.627967     8
# 8     3.594833  42.529460      26.403455              35.191020     9
# 9     3.905158  45.688746      25.386448              38.023925    10
# 10    3.829722  42.041723      25.429505              38.249354    11
# 11    4.336721  46.320224      22.926193              35.973614    12
# 12    3.545367  42.006243      24.803186              40.018521    13
# 13    3.716954  43.084501      22.360116              33.097737    14
# 14    3.521416  42.847368      25.441090              38.994995    15
# 15    3.545971  42.668398      27.147615              38.034450    16
# 16    3.474807  41.201290      27.500000              36.166328    17
# 17    3.343690  42.737538      27.568541              35.340193    18
# 18    3.474136  43.199551      24.784372              36.692008    19
# 19    4.414344  45.176407      27.274720              34.718954    20

# %%
df_time.plot(x='fold', y=['ANN', 'ElasticNet', 'RSQTOA + Grid', 'RSQTOA + Interpolator'], marker='o')
plt.xticks(np.arange(1, 21, 2.0))
plt.yticks(np.arange(0, 85, 10.0))
plt.ylabel('Training Time (sec)')
plt.xlabel('Fold')
plt.savefig('yelp_train_time_comparison.png', dpi = 300)

# %%
df_rmse = pd.concat([df_results_lr['test_rmse'], df_results_ann['test_rmse'], df_results_grid['test_rmse'], df_results_interpolator['test_rmse']], axis=1, keys=['ElasticNet', 'ANN', 'RSQTOA + Grid', 'RSQTOA + Interpolator'])
df_rmse['fold'] = list(range(1, 21))
df_rmse
# Out:
#     ElasticNet       ANN  RSQTOA + Grid  RSQTOA + Interpolator  fold
# 0     0.092835  0.097802       0.100032               0.167065     1
# 1     0.092982  0.097392       0.099593               0.118030     2
# 2     0.095610  0.100449       0.103203               0.135680     3
# 3     0.093505  0.098259       0.102509               0.161891     4
# 4     0.089712  0.093925       0.097231               0.109322     5
# 5     0.093116  0.098291       0.102734               0.119355     6
# 6     0.094302  0.099912       0.102237               0.169145     7
# 7     0.088837  0.093441       0.094833               0.116622     8
# 8     0.093984  0.098569       0.105499               0.120840     9
# 9     0.090359  0.095980       0.101399               0.126954    10
# 10    0.092122  0.097949       0.102536               0.111670    11
# 11    0.091911  0.096317       0.101392               0.168980    12
# 12    0.092584  0.097894       0.099665               0.164120    13
# 13    0.090458  0.095607       0.100158               0.121117    14
# 14    0.096076  0.100990       0.108025               0.173802    15
# 15    0.092427  0.097608       0.098268               0.127328    16
# 16    0.093337  0.098595       0.104745               0.150262    17
# 17    0.094938  0.100405       0.105269               0.137997    18
# 18    0.090069  0.094984       0.096193               0.137428    19
# 19    0.091971  0.097122       0.100304               0.166862    20

# %%
df_rmse.plot(x='fold', y=['ANN', 'ElasticNet', 'RSQTOA + Grid', 'RSQTOA + Interpolator'], marker='o')
plt.xticks(np.arange(1, 21, 1.0))
plt.yticks(np.arange(0.08, 0.25, 0.02))
plt.ylabel('RMSE')
plt.xlabel('Fold')
plt.show()

# %%
df_r2 = pd.concat([df_results_lr['test_r2'], df_results_ann['test_r2'], df_results_grid['test_r2'], df_results_interpolator['test_r2']], axis=1, keys=['ElasticNet', 'ANN', 'RSQTOA + Grid', 'RSQTOA + Interpolator'])
df_r2['fold'] = list(range(1, 21))
df_r2
# Out:
#     ElasticNet       ANN  RSQTOA + Grid  RSQTOA + Interpolator  fold
# 0     0.674694  0.701189       0.687407               0.128081     1
# 1     0.681853  0.711129       0.697924               0.575727     2
# 2     0.675257  0.703338       0.686849               0.458745     3
# 3     0.691501  0.718052       0.693139               0.234636     4
# 4     0.694496  0.722851       0.702993               0.624536     5
# 5     0.689669  0.713819       0.687359               0.578015     6
# 6     0.678148  0.700994       0.686916               0.143031     7
# 7     0.710417  0.734846       0.726886               0.586968     8
# 8     0.707502  0.733727       0.694969               0.599806     9
# 9     0.695895  0.716031       0.683059               0.503171    10
# 10    0.699369  0.718717       0.691757               0.634391    11
# 11    0.687698  0.716156       0.685455               0.126333    12
# 12    0.689759  0.712939       0.702457               0.193156    13
# 13    0.699782  0.722445       0.695391               0.554564    14
# 14    0.673939  0.701831       0.658843               0.116891    15
# 15    0.671601  0.696885       0.692770               0.484194    16
# 16    0.668289  0.693662       0.654256               0.288475    17
# 17    0.661538  0.686685       0.655595               0.408158    18
# 18    0.690824  0.715426       0.708136               0.404285    19
# 19    0.682445  0.706920       0.687404               0.134902    20

# %%
df_r2.plot(x='fold', y=['ANN', 'ElasticNet', 'RSQTOA + Grid', 'RSQTOA + Interpolator'], marker='o')
plt.xticks(np.arange(1, 21, 2.0))
plt.yticks(np.arange(0, 1.3, 0.2))
plt.ylabel('$R^2$ Score')
plt.xlabel('Fold')
plt.savefig('yelp_r2_comparison.png', dpi = 300)

# %%
df_loss = pd.DataFrame(columns=['ann_train_loss', 'ann_val_loss'])
for i in range(1, 21):
    df_loss_ann = pd.read_csv('./ann/loss_hist_{}.csv'.format(i))
    df_loss_grid = pd.read_csv('./grid/loss_hist_{}.csv'.format(i))
    df_loss_interpolator = pd.read_csv('./interpolator/loss_hist_{}.csv'.format(i))

    if df_loss.shape[0] is 0:
        df_loss['ann_train_loss'] = df_loss_ann['train_loss']
        df_loss['ann_val_loss'] = df_loss_ann['val_loss']

        df_loss['grid_train_loss'] = df_loss_grid['train_loss']
        df_loss['grid_val_loss'] = df_loss_grid['val_loss']

        df_loss['interpolator_train_loss'] = df_loss_interpolator['train_loss']
        df_loss['interpolator_val_loss'] = df_loss_interpolator['val_loss']
    else:
        df_loss['ann_train_loss'] += df_loss_ann['train_loss']
        df_loss['ann_val_loss'] += df_loss_ann['val_loss']

        df_loss['grid_train_loss'] += df_loss_grid['train_loss']
        df_loss['grid_val_loss'] += df_loss_grid['val_loss']

        df_loss['interpolator_train_loss'] += df_loss_interpolator['train_loss']
        df_loss['interpolator_val_loss'] += df_loss_interpolator['val_loss']

df_loss /= 20
df_loss
# Out:
#     ann_train_loss  ann_val_loss  grid_train_loss  grid_val_loss  \
# 0         0.189194      0.150538         0.267009       0.214981
# 1         0.139964      0.132346         0.196691       0.180161
# 2         0.127481      0.124298         0.173625       0.165153
# 3         0.121571      0.120226         0.162814       0.158005
# 4         0.118518      0.118021         0.157720       0.153655
# ..             ...           ...              ...            ...
# 95        0.097281      0.097857         0.102182       0.099908
# 96        0.097281      0.097835         0.101975       0.099879
# 97        0.097275      0.097854         0.101842       0.099829
# 98        0.097269      0.097795         0.101934       0.099739
# 99        0.097254      0.097817         0.101898       0.099753
#
#     interpolator_train_loss  interpolator_val_loss
# 0                  0.482131               0.394227
# 1                  0.351165               0.318266
# 2                  0.300979               0.287343
# 3                  0.277749               0.269020
# 4                  0.261642               0.254925
# ..                      ...                    ...
# 95                 0.164291               0.163416
# 96                 0.163748               0.162955
# 97                 0.163500               0.162559
# 98                 0.163119               0.162020
# 99                 0.162638               0.161879
#
# [100 rows x 6 columns]

# %%
plt.plot(df_loss['ann_train_loss'])
plt.plot(df_loss['ann_val_loss'])
plt.yticks(np.arange(0.0, 0.5, 0.08))
# plt.title('Model loss ANN')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.savefig('yelp_residual_ann.png', dpi = 300)

# %%
plt.plot(df_loss['grid_train_loss'])
plt.plot(df_loss['grid_val_loss'])
plt.yticks(np.arange(0.0, 0.5, 0.08))
# plt.title('Model loss Grid')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.savefig('yelp_residual_grid.png', dpi = 300)

# %%
plt.plot(df_loss['interpolator_train_loss'])
plt.plot(df_loss['interpolator_val_loss'])
plt.yticks(np.arange(0.0, 0.5, 0.08))
# plt.title('Model loss Interpolator')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.savefig('yelp_residual_interpolator.png', dpi = 300)
